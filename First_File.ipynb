# %% [markdown]
# # this is the first notebook of mine
# - i learn in the this lecture how does jupyter notebook works
# - how cells runs
# - markdown
# - server and kernal of jupyter notebook

# %%
print("hello to my datascience jorney")
# Out:
# hello to my datascience jorney

# %%
a = 12

# %%
b = 20

# %%
a + b
# Out:
# 32
